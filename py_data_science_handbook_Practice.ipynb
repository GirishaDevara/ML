# %% [markdown]
# # shall commands

# %%
# !ls
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 8A01-9EFB
#
#  Directory of C:\Users\divya\Desktop\ML
#
# 09/24/2019  10:07 PM    <DIR>          .
# 09/24/2019  10:07 PM    <DIR>          ..
# 09/24/2019  10:06 PM    <DIR>          .ipynb_checkpoints
# 09/23/2019  11:41 PM    <DIR>          apds
# 09/23/2019  09:22 PM           108,480 ML_sample.ipynb
# 09/19/2019  10:43 AM    <DIR>          MLND
# 09/18/2019  12:42 PM             8,529 Practice.ipynb
# 09/24/2019  10:07 PM               883 py_data_science_handbook_Practice.ipynb
# 09/23/2019  09:13 PM        22,321,280 Python Data Science Handbook.pdf
# 09/23/2019  09:14 PM            61,194 train.csv
#                5 File(s)     22,500,366 bytes
#                5 Dir(s)  23,453,642,752 bytes free

# %%
pwd
# Out:
# 'C:\\Users\\divya\\Desktop\\ML'

# %%
# !pwd
# Out:
# 'pwd' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# %%timeit
echo hi
# Out:
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# ...

# %%
cd ..
# Out:
# C:\Users\divya\Desktop

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 8A01-9EFB
#
#  Directory of C:\Users\divya\Desktop
#
# 09/23/2019  10:08 PM    <DIR>          .
# 09/23/2019  10:08 PM    <DIR>          ..
# 09/19/2019  10:43 AM    <DIR>          apssdc-aiet-mstp-aug-2019-master
# 09/20/2019  03:17 PM    <DIR>          assignmets
# 09/20/2019  09:56 AM            63,480 drive-download-20190920T042615Z-001.zip
# 07/10/2018  08:24 AM         8,710,858 Exercise_Guide.pdf
# 04/05/2018  10:24 AM             2,537 Grammarly.lnk
# 09/24/2019  10:09 PM    <DIR>          ML
# 08/16/2018  11:58 PM             2,691 Outlook 2013.lnk
# 08/03/2018  09:14 PM            98,304 Pearson VUE - Online Exam History.pdf
# 07/09/2018  10:27 AM             1,128 Pega 7.4.0 Login.lnk
# 07/09/2018  10:27 AM             1,887 Pega 7.4.0 Shutdown.lnk
# 07/09/2018  10:27 AM             1,890 Pega 7.4.0 Startup.lnk
# 09/23/2019  10:20 PM    <DIR>          probelm-solving-and-programming-in-python-level2-2019
# ...

# %%
cd ML
# Out:
# C:\Users\divya\Desktop\ML

# %%
pwd
# Out:
# 'C:\\Users\\divya\\Desktop\\ML'

# %% [markdown]
# # Data manipulating with pandas

# %%
import pandas as pd
pd.__version__
# Out:
# '0.24.2'
